# %%
# !pip install deepforest
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 43.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 66.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 53.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 55.3 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python

# %%
import deepforest
import cv2

# %%
img_path = "/Copy of Screenshot 2023-10-12 204424.png"
img = cv2.imread(img_path)

# %%
import cv2
from IPython.display import Image, display

# Load and display an image
img = cv2.imread('/Copy of Screenshot 2023-10-12 204424.png')
display(Image(data=img))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import deepforest

# Create an instance of the deepforest model
my_model = deepforest()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1e09cff87b18> in <cell line: 4>()
#       2
#       3 # Create an instance of the deepforest model
# ----> 4 my_model = deepforest.deepforest()
#
# AttributeError: module 'deepforest' has no attribute 'deepforest'

# %%
pip install deepforest

# %%
import cv2
from deepforest import deepforest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-9e33c7797df6> in <cell line: 2>()
#       1 import cv2
# ----> 2 from deepforest import deepforest
#
# ImportError: cannot import name 'deepforest' from 'deepforest' (/usr/local/lib/python3.10/dist-packages/deepforest/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install git+https://github.com/deforest2020/deepforest.git
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package git+https://github.com/deforest2020
